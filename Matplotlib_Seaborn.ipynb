# %%
import matplotlib.pyplot as plt

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.8.0

# %%
x=[244,345,400,200,150]
mylables=['Swift','Dzire','WagoR','Breeza','Alto']
plt.pie(x,labels=mylables,autopct="%.2f")
plt.legend()
plt.show()

# %%
plt.pie(x,labels=mylables,autopct="%.2f",explode=[0.2,0,0,0,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x14efdbe50>,
# ...
#  [Text(1.0927292436978677, 0.7042320640012681, 'Swift'),
#   Text(-0.41169498141505934, 1.020052568389323, 'Dzire'),
#   Text(-0.9315437029304099, -0.5850011363499223, 'WagoR'),
#   Text(0.4260133937609684, -1.014156096632201, 'Breeza'),
#   Text(1.03257879636388, -0.37918469022327544, 'Alto')],
#  [Text(0.672448765352534, 0.43337357784693425, '18.22'),
#   Text(-0.2245608989536687, 0.5563923100305397, '25.77'),
#   Text(-0.5081147470529508, -0.31909152891813947, '29.87'),
#   Text(0.2323709420514373, -0.5531760527084733, '14.94'),
#   Text(0.5632247980166617, -0.2068280128490593, '11.20')])

# %%
x=[1,2,3,4,5]
y=[5,6,7,8,9]
plt.plot(x,y)

# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/mayurmore/Desktop/ML/insurance.csv')

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
plt.bar(data['sex'],data['age'])
# Out:
# <BarContainer object of 1338 artists>

# %%
plt.hist(data['age'])
# Out:
# (array([222., 140., 109., 128., 102., 137., 144., 114., 128., 114.]),
#  array([18. , 22.6, 27.2, 31.8, 36.4, 41. , 45.6, 50.2, 54.8, 59.4, 64. ]),
#  <BarContainer object of 10 artists>)

# %%
data['children'].value_counts()
# Out:
# children
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
a=data['smoker'].value_counts()
a.index
# Out:
# Index(['no', 'yes'], dtype='object', name='smoker')

# %%
a.values
# Out:
# array([1064,  274])

# %%
colors=['green','red']
plt.bar(a.index,a.values,color=colors)
plt.title('Smoker Counts')
# Out:
# Text(0.5, 1.0, 'Smoker Counts')

# %%
abc=data['region'].value_counts()
plt.pie(abc.values,labels=abc.index,autopct='%.2f%%')
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.subplot(2,2,1)
plt.plot(data['age'],data['bmi'])

plt.subplot(2,2,2)
plt.plot(data['age'],data['charges'])

plt.subplot(2,2,3)
plt.plot(data['age'],data['bmi'])

plt.subplot(2,2,4)
plt.plot(data['age'],data['charges'])

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
data=sns.load_dataset('titanic')

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data['alive'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       no
# 1      yes
# 2      yes
# 3      yes
# 4       no
#       ...
# 886     no
# 887    yes
# 888     no
# 889    yes
# 890     no
# Name: alive, Length: 891, dtype: object>

# %%
import numpy as np

# %%
xp=np.array([0,6])
yp=np.array([0,250])
plt.plot(xp,yp,marker='o',ms=10,mfc='g')

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])


plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(1,3,1)

plt.plot(x,y)
plt.subplot(1,3,2)
plt.plot(x,y)
plt.subplot(1,3,3)
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np

#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()
